# %%
import pandas as pd
from sqlalchemy import create_engine, text
import pymysql.cursors
import os
# import getpass
import urllib.parse

# %%
battles = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/battles.csv')
battles
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\496118513.py:1: SyntaxWarning: invalid escape sequence '\D'
#   battles = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/battles.csv')
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# ...

# %%
deaths = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/character-deaths.csv')
deaths
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\2562306490.py:1: SyntaxWarning: invalid escape sequence '\D'
#   deaths = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/character-deaths.csv')
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo              NaN         NaN            NaN
# ...

# %%
predictions = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/character-predictions.csv')
predictions
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\136615200.py:1: SyntaxWarning: invalid escape sequence '\D'
#   predictions = pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/character-predictions.csv')
#       S.No  actual  pred  alive   plod                  name  \
# 0        1       0     0  0.054  0.946  Viserys II Targaryen
# 1        2       1     0  0.387  0.613           Walder Frey
# 2        3       1     0  0.493  0.507          Addison Hill
# 3        4       0     0  0.076  0.924           Aemma Arryn
# 4        5       1     1  0.617  0.383        Sylva Santagar
# ...    ...     ...   ...    ...    ...                   ...
# 1941  1942       0     1  0.803  0.197                 Luwin
# 1942  1943       0     1  0.987  0.013                  Reek
# ...

# %%
deaths2= pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/game_of_thrones_character_deaths.csv')
deaths2
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\1936428243.py:1: SyntaxWarning: invalid escape sequence '\D'
#   deaths2= pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/game_of_thrones_character_deaths.csv')
#                         name      allegiances  death_year  book_of_death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo              NaN         NaN            NaN
# ...

# %%
tv_stats= pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/Game_of_Thrones.csv')
deaths
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\1303376559.py:1: SyntaxWarning: invalid escape sequence '\D'
#   tv_stats= pd.read_csv('D:\Docs Persos\IRONHACK_BC\labs\week_6_flask_bigquery_spotipy_MLintro\Games of Thrones lab\game_of_thrones\data/Game_of_Thrones.csv')
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo              NaN         NaN            NaN
# ...

# %%
pw_raw = 'Silver57' #os.getenv('ironhack')
pw = urllib.parse.quote_plus(pw_raw)

# %%
connection_string = 'mysql+pymysql://root:' + pw + '@localhost:3306/GOT'
engine = create_engine(connection_string)

# %%
battles.to_sql('battles',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\4059464282.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   battles.to_sql('battles',engine, 'GOT', if_exists='replace', index=False)
# 38

# %%
deaths.to_sql('deaths',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\2737440207.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   deaths.to_sql('deaths',engine, 'GOT', if_exists='replace', index=False)
# 917

# %%
deaths2.to_sql('death2',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\3593918782.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   deaths2.to_sql('death2',engine, 'GOT', if_exists='replace', index=False)
# 917

# %%
predictions.to_sql('predictions',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\2793547669.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   predictions.to_sql('predictions',engine, 'GOT', if_exists='replace', index=False)
# 1946

# %%
tv_stats.to_sql('tv_stats',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\2016522275.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   tv_stats.to_sql('tv_stats',engine, 'GOT', if_exists='replace', index=False)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1970, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969     if not evt_handled:
# -> 1970         self.dialect.do_execute(
#    1971             cursor, str_statement, effective_parameters, context
#    1972         )
#    1974 if self._has_events or self.engine._has_events:
#
# ...

# %%
predictions.rename(columns={'S.No': 'character_id'}, inplace=True)
predictions
# Out:
#       character_id  actual  pred  alive   plod                  name  \
# 0                1       0     0  0.054  0.946  Viserys II Targaryen
# 1                2       1     0  0.387  0.613           Walder Frey
# 2                3       1     0  0.493  0.507          Addison Hill
# 3                4       0     0  0.076  0.924           Aemma Arryn
# 4                5       1     1  0.617  0.383        Sylva Santagar
# ...            ...     ...   ...    ...    ...                   ...
# 1941          1942       0     1  0.803  0.197                 Luwin
# 1942          1943       0     1  0.987  0.013                  Reek
# 1943          1944       1     1  0.520  0.480      Symeon Star-Eyes
# 1944          1945       1     1  0.637  0.363             Coldhands
# 1945          1946       0     0  0.093  0.907       Tytos Lannister
#
#                      title  male   culture  dateOfBirth  ...  isAliveHeir  \
# ...

# %%
predictions.to_sql('predictions',engine, 'GOT', if_exists='replace', index=False)
# Out:
# C:\Users\micel\AppData\Local\Temp\ipykernel_14380\2793547669.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_sql except for the arguments 'name' and 'con' will be keyword-only.
#   predictions.to_sql('predictions',engine, 'GOT', if_exists='replace', index=False)
# 1946
